# %%
from cmodels.cc_cmodel import cc_cmodel
from cmodels.cc_cmodel_sol import cc_cmodel_sol

from mmodels.xu_bb.cc_xu_bb import cc_xu_bb

from cell_tracking.cell_tracking import cell_tracking

# %%
import pandas as pd
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading compartment model

# %%
STR_LS_GNR = cc_cmodel(excel_path='cmodels/cmodel_files/RTD_LS/9_RTD_LS.xlsx')

# %%
complex_mmodel = cc_xu_bb(
    strain_id='Xu et al. 1999 literature strain',
    strain_description='WT E. coli'
)

complex_mmodel.define_strain_params(
    qS_max=1.3,
    qm_max=0.04,
    qA_c_max=0.15,
    qO_max=15,
    Ysx_ox=0.5,
    Ysx_of=0.15,
    Ysa=0.667,
    Yax=0.4,
    Ki_s=5,
    Ks=0.05,
    Ka=0.05,
    Ki_o=4
)

# %% [markdown]
# ## Solving compartment model

# %%
y0_1d = [
    0.0, #S 
    0.2095, #O
    0 #A
    ]

# multiply initial values with the number of compartments
y0 = y0_1d*len(STR_LS_GNR.CompVolumes)
# simulation time
t_eval=np.linspace(0,1,10001)
# Biomass concentration 
X = 20 # to keep things consistent: A biomass concentration of 40 g/L was chosen for Ys = 0.5; hence Ysx = 0.52 should result in 41.6. This is to keep the glucose feed rate constant accross different examples. 
# Growth rate for the fed-batch
mu_set = 0.05
# Liquid volume in the whole reactor
VL = (STR_LS_GNR.CompVolumes.CompVol - STR_LS_GNR.CompVolumes.CompVol*STR_LS_GNR.GH.GH).sum()
# Biomass yield
Ysx = complex_mmodel.Ysx_ox
# Glucose feed rate
Fs_feed = mu_set/Ysx*X*VL*1000
# compartment model instance
cmodel = STR_LS_GNR

sol = cc_cmodel_sol(
    y0 = y0,
    t_eval = t_eval, 
    mmodel = complex_mmodel, 
    cmodel = cmodel, 
    X = X, 
    Fs_feed = Fs_feed
)

# %%
sol.plot_solution()
# Out:
# c:\Users\jonas\OneDrive\Desktop\process_sim_and_scale-down_design\process_sim_and_scale-down_design\cmodels\cc_cmodel_sol.py:49: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = mpl.pyplot.subplots(figsize=(2.5, 11))
